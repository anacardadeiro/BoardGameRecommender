# %% [markdown]
# **`Exercise 2`**.Build a recommender system in a new notebook for recommending books from goodreads, using the following datasets:
#
#
# `- 5.4.1.books-ratings.csv`
#
#
# `- 5.4.1.books-info.csv`
#
#
# Test the recommender with the book_id = 10!

# %% [markdown]
# # Load the data

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
ratings = pd.read_csv("C:/Users/linco/Desktop/datastudy/DScourse/_module5_/_module5_/notebooks/5.4. Unsupervised_Association/GBB/bgg-15m-reviews.csv")
ratings
# Out:
#           Unnamed: 0             user  rating  \
# 0                  0          Torsten    10.0
# 1                  1  mitnachtKAUBO-I    10.0
# 2                  2           avlawn    10.0
# 3                  3       Mike Mayer    10.0
# 4                  4          Mease19    10.0
# ...              ...              ...     ...
# 15823264    15823264         Fafhrd65     8.0
# 15823265    15823265       PlatinumOh     8.0
# 15823266    15823266       BunkerBill     7.0
# 15823267    15823267    Hattori Hanzo     6.0
# 15823268    15823268       Richie2000     1.0
#
#                                                     comment      ID  \
# 0                                                       NaN   30549
# 1         Hands down my favorite new game of BGG CON 200...   30549
# 2         I tend to either love or easily tire of co-op ...   30549
# 3                                                       NaN   30549
# 4         This is an amazing co-op game.  I play mostly ...   30549
# ...                                                     ...     ...
# 15823264  Turn based preview looks very promising. The g...  281515
# 15823265                                                 KS  281515
# 15823266                                                NaN  281515
# 15823267                                                NaN  281515
# 15823268                                                NaN  281515
#
#                        name
# 0                  Pandemic
# 1                  Pandemic
# 2                  Pandemic
# 3                  Pandemic
# 4                  Pandemic
# ...                     ...
# 15823264  Company of Heroes
# 15823265  Company of Heroes
# 15823266  Company of Heroes
# 15823267  Company of Heroes
# 15823268  Company of Heroes
#
# [15823269 rows x 6 columns]

# %%
ratings.columns
# Out:
# Index(['Unnamed: 0', 'user', 'rating', 'comment', 'ID', 'name'], dtype='object')

# %%
ratings.drop(["Unnamed: 0", "comment"], axis=1, inplace=True)

# %%
ratings.head()
# Out:
#               user  rating     ID      name
# 0          Torsten    10.0  30549  Pandemic
# 1  mitnachtKAUBO-I    10.0  30549  Pandemic
# 2           avlawn    10.0  30549  Pandemic
# 3       Mike Mayer    10.0  30549  Pandemic
# 4          Mease19    10.0  30549  Pandemic

# %%
ratings.rename(mapper={"user":"user_id", "ID":"game_id", "name":"title"}, axis=1, inplace=True)
ratings.head()
# Out:
#            user_id  rating  game_id     title
# 0          Torsten    10.0    30549  Pandemic
# 1  mitnachtKAUBO-I    10.0    30549  Pandemic
# 2           avlawn    10.0    30549  Pandemic
# 3       Mike Mayer    10.0    30549  Pandemic
# 4          Mease19    10.0    30549  Pandemic

# %%
ratings.columns
# Out:
# Index(['user_id', 'rating', 'game_id', 'title'], dtype='object')

# %%
info = ratings[["game_id","title"]]
info
# Out:
#           game_id              title
# 0           30549           Pandemic
# 1           30549           Pandemic
# 2           30549           Pandemic
# 3           30549           Pandemic
# 4           30549           Pandemic
# ...           ...                ...
# 15823264   281515  Company of Heroes
# 15823265   281515  Company of Heroes
# 15823266   281515  Company of Heroes
# 15823267   281515  Company of Heroes
# 15823268   281515  Company of Heroes
#
# [15823269 rows x 2 columns]

# %%
info.drop_duplicates(inplace=True)
info
# Out:
# C:\Users\linco\AppData\Local\Temp\ipykernel_9816\999174464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info.drop_duplicates(inplace=True)
#           game_id                        title
# 0           30549                     Pandemic
# 100           822                  Carcassonne
# 200            13                        Catan
# 300         68448                    7 Wonders
# 400         36218                     Dominion
# ...           ...                          ...
# 15823119   246345                   Ninja Rush
# 15823149   195623  Politricks: Dirty Card Game
# 15823179   235943                     Doppel X
# 15823209   284862               Beasty Borders
# 15823239   281515            Company of Heroes
#
# [19330 rows x 2 columns]

# %%
ratings.game_id.nunique()
# Out:
# 19330

# %% [markdown]
# # Exploratory Analysis

# %%
# number of users

ratings.user_id.nunique()
# Out:
# 351048

# %%
# number of books
ratings.game_id.nunique()
# Out:
# 19330

# %%
# number of ratings per user
userfreq = ratings[["user_id", "game_id"]].groupby("user_id").count().reset_index()
userfreq.columns = ["user_id","no_ratings"]
userfreq.sort_values(by="no_ratings")
# Out:
#                      user_id  no_ratings
# 84277                Khaisor           1
# 204393      christophersisto           1
# 204392       christophermrau           1
# 204391  christophermorrison2           1
# 204389    christophergodfrey           1
# ...                      ...         ...
# 66952                Hessu68        4602
# 342435                 warta        4811
# 41655                   Doel        4876
# 161600              TomVasel        4950
# 267289          leffe dubbel        6027
#
# [351048 rows x 2 columns]

# %% [markdown]
# # Bahesian stats

# %%
gamestats = ratings.groupby("game_id")["rating"].agg(["count","mean"])
gamestats.head(10)
# Out:
#          count      mean
# game_id
# 1         5089  7.630658
# 2          544  6.613411
# 3        14393  7.445493
# 4          337  6.612821
# 5        17838  7.344081
# 6           81  6.479630
# 7         3150  6.520788
# 8          197  6.147411
# 9         1358  6.467161
# 10        7855  6.717890

# %%
C=gamestats["count"].mean()
m=gamestats["mean"].mean()

# %%
def bayesian_avg(ratings):
    bayesian_avg = (C*m+ratings.sum()) / (C+ratings.count())
    return bayesian_avg

# %%
bayesavg_ratings = ratings.groupby("game_id")["rating"].agg(bayesian_avg).reset_index()
bayesavg_ratings.columns = ["game_id","bayesian_avg"]
bayesavg_ratings.head(5)
# Out:
#    game_id  bayesian_avg
# 0        1      7.459099
# 1        2      6.480725
# 2        3      7.388831
# 3        4      6.456785
# 4        5      7.302331

# %%
gamestats = gamestats.merge(bayesavg_ratings, on="game_id")
gamestats.head(10)
# Out:
#    game_id  count      mean  bayesian_avg
# 0        1   5089  7.630658      7.459099
# 1        2    544  6.613411      6.480725
# 2        3  14393  7.445493      7.388831
# 3        4    337  6.612821      6.456785
# 4        5  17838  7.344081      7.302331
# 5        6     81  6.479630      6.400389
# 6        7   3150  6.520788      6.494336
# 7        8    197  6.147411      6.344997
# 8        9   1358  6.467161      6.439100
# 9       10   7855  6.717890      6.687185

# %%
gamestats = gamestats.merge(info[["game_id","title"]], on="game_id")
gamestats.head(10)
# Out:
#    game_id  count      mean  bayesian_avg               title
# 0        1   5089  7.630658      7.459099          Die Macher
# 1        2    544  6.613411      6.480725        Dragonmaster
# 2        3  14393  7.445493      7.388831             Samurai
# 3        4    337  6.612821      6.456785      Tal der Könige
# 4        5  17838  7.344081      7.302331             Acquire
# 5        6     81  6.479630      6.400389  Mare Mediterraneum
# 6        7   3150  6.520788      6.494336           Cathedral
# 7        8    197  6.147411      6.344997   Lords of Creation
# 8        9   1358  6.467161      6.439100        El Caballero
# 9       10   7855  6.717890      6.687185           Elfenland

# %% [markdown]
# # Building the recommender system

# %% [raw]
# first step of collaborative filtering is to transform our data into a user-item matrix - also known as a "utility" matrix
#
# The create_X() function outputs a sparse matrix X with four mapper dictionaries:
# user_mapper: maps user id to user index
# movie_mapper: maps movie id to movie index
# user_inv_mapper: maps user index to user id
# movie_inv_mapper: maps movie index to movie id
#
# We need these dictionaries because they map which row and column of the utility matrix corresponds to which user ID and movie ID, respectively.
#
# The X (user-item) matrix is a scipy.sparse.csr_matrix which stores the data sparsely

# %% [markdown]
# ## dictionaries

# %%
gametitles = dict(zip(info["game_id"], info["title"]))
gametitles
# Out:
# {30549: 'Pandemic',
#  822: 'Carcassonne',
#  13: 'Catan',
#  68448: '7 Wonders',
#  36218: 'Dominion',
#  9209: 'Ticket to Ride',
#  178900: 'Codenames',
#  31260: 'Agricola',
#  3076: 'Puerto Rico',
#  40692: 'Small World',
#  167791: 'Terraforming Mars',
#  70323: 'King of Tokyo',
#  14996: 'Ticket to Ride: Europe',
#  148228: 'Splendor',
#  2651: 'Power Grid',
#  173346: '7 Wonders Duel',
#  129622: 'Love Letter',
#  169786: 'Scythe',
#  39856: 'Dixit',
#  478: 'Citadels',
#  230802: 'Azul',
#  28143: 'Race for the Galaxy',
#  110327: 'Lords of Waterdeep',
#  84876: 'The Castles of Burgundy',
#  34635: 'Stone Age',
#  163412: 'Patchwork',
#  1927: 'Munchkin',
#  65244: 'Forbidden Island',
#  12333: 'Twilight Struggle',
#  161936: 'Pandemic Legacy: Season 1',
#  150376: 'Dead of Winter: A Crossroads Game',
#  120677: 'Terra Mystica',
#  174430: 'Gloomhaven',
#  11: 'Bohnanza',
#  98778: 'Hanabi',
#  15987: 'Arkham Horror',
#  50: 'Lost Cities',
#  10547: 'Betrayal at House on the Hill',
#  41114: 'The Resistance',
#  54043: 'Jaipur',
#  131357: 'Coup',
#  147020: 'Star Realms',
#  70919: 'Takenoko',
#  266192: 'Wingspan',
#  133473: 'Sushi Go!',
#  37111: 'Battlestar Galactica: The Board Game',
#  121921: 'Robinson Crusoe: Adventures on the Cursed Island',
#  170216: 'Blood Rage',
#  463: 'Magic: The Gathering',
#  157354: 'Five Tribes',
#  181304: 'Mysterium',
#  40834: 'Dominion: Intrigue',
#  181: 'Risk',
#  126163: "Tzolk'in: The Mayan Calendar",
#  204583: 'Kingdomino',
#  31481: 'Galaxy Trucker',
#  2655: 'Hive',
#  157969: 'Sheriff of Nottingham',
#  146021: 'Eldritch Horror',
#  6249: 'Alhambra',
#  103343: 'A Game of Thrones: The Board Game (Second Edition)',
#  171: 'Chess',
#  102794: 'Caverna: The Cave Farmers',
#  1406: 'Monopoly',
#  96848: 'Mage Knight Board Game',
#  193738: 'Great Western Trail',
#  39463: 'Cosmic Encounter',
#  18602: 'Caylus',
#  124742: 'Android: Netrunner',
#  128882: 'The Resistance: Avalon',
#  183394: 'Viticulture Essential Edition',
#  124361: 'Concordia',
#  72125: 'Eclipse',
#  3955: 'BANG!',
#  320: 'Scrabble',
#  35677: 'Le Havre',
#  205637: 'Arkham Horror: The Card Game',
#  15062: 'Shadows over Camelot',
#  132531: 'Roll for the Galaxy',
#  10630: "Memoir '44",
#  201808: 'Clank!: A Deck-Building Adventure',
#  42: 'Tigris & Euphrates',
#  143884: 'Machi Koro',
#  194655: 'Santorini',
#  136063: 'Forbidden Desert',
#  9220: 'Saboteur',
#  148949: 'Istanbul',
#  158899: 'Colt Express',
#  93: 'El Grande',
#  122522: 'Smash Up',
#  172: 'For Sale',
#  205059: 'Mansions of Madness: Second Edition',
#  199561: 'Sagrada',
#  146508: 'T.I.M.E Stories',
#  103885: 'Star Wars: X-Wing Miniatures Game',
#  16992: 'Tsuro',
#  50381: 'Cards Against Humanity',
#  18: 'RoboRally',
#  2453: 'Blokus',
#  104162: 'Descent: Journeys in the Dark (Second Edition)',
#  8217: 'San Juan',
#  153938: 'Camel Up',
#  100423: 'Elder Sign',
#  155426: 'Castles of Mad King Ludwig',
#  187645: 'Star Wars: Rebellion',
#  182028: 'Through the Ages: A New Story of Civilization',
#  123260: 'Suburbia',
#  162886: 'Spirit Island',
#  164928: 'Orléans',
#  100901: 'Flash Point: Fire Rescue',
#  147949: 'One Night Ultimate Werewolf',
#  154203: 'Imperial Settlers',
#  77423: 'The Lord of the Rings: The Card Game',
#  108745: 'Seasons',
#  2223: 'UNO',
#  192291: 'Sushi Go Party!',
#  12942: 'No Thanks!',
#  104006: 'Village',
#  2653: 'Survive: Escape from Atlantis!',
#  164153: 'Star Wars: Imperial Assault',
#  123540: 'Tokaido',
#  129437: 'Legendary: A Marvel Deck Building Game',
#  172225: 'Exploding Kittens',
#  176494: 'Isle of Skye: From Chieftain to King',
#  432: '6 nimmt!',
#  116: 'Guillotine',
#  237182: 'Root',
#  37046: 'Ghost Stories',
#  8203: "Hey, That's My Fish!",
#  143741: 'BANG! The Dice Game',
#  171623: 'The Voyages of Marco Polo',
#  12: 'Ra',
#  107529: 'Kingdom Builder',
#  28720: 'Brass: Lancashire',
#  122515: 'Keyflower',
#  27162: 'Kingsburg',
#  12493: 'Twilight Imperium (Third Edition)',
#  5: 'Acquire',
#  25613: 'Through the Ages: A Story of Civilization',
#  73439: 'Troyes',
#  21790: 'Thurn and Taxis',
#  166384: 'Spyfall',
#  54: 'Tikal',
#  62219: 'Dominant Species',
#  5782: 'Coloretto',
#  161970: 'Alchemists',
#  74: 'Apples to Apples',
#  54998: 'Cyclades',
#  209685: 'Century: Spice Road',
#  244521: 'The Quacks of Quedlinburg',
#  1294: 'Clue',
#  37904: 'Formula D',
#  244992: 'The Mind',
#  188834: 'Secret Hitler',
#  15512: 'Diamant',
#  2511: 'Sherlock Holmes Consulting Detective: The Thames Murders & Other Cases',
#  124708: 'Mice and Mystics',
#  118: 'Modern Art',
#  24480: 'The Pillars of the Earth',
#  113924: 'Zombicide',
#  198773: 'Codenames: Pictures',
#  92828: 'Dixit: Odyssey',
#  62871: 'Zombie Dice',
#  28023: 'Jamaica',
#  127023: 'Kemet',
#  177736: 'A Feast for Odin',
#  258: 'Fluxx',
#  43570: 'Friday',
#  25669: 'Qwirkle',
#  9674: 'Ingenious',
#  760: 'Battle Line',
#  113294: 'Escape: The Curse of the Temple',
#  171131: 'Captain Sonar',
#  218603: 'Photosynthesis',
#  180263: 'The 7th Continent',
#  156129: 'Deception: Murder in Hong Kong',
#  21763: 'Mr. Jack',
#  224517: 'Brass: Birmingham',
#  163967: 'Tiny Epic Galaxies',
#  199792: 'Everdell',
#  38453: 'Space Alert',
#  555: 'The Princes of Florence',
#  205896: 'Rising Sun',
#  34219: 'Biblios',
#  3: 'Samurai',
#  102652: 'Sentinels of the Multiverse',
#  147151: 'Concept',
#  188: 'Go',
#  220308: 'Gaia Project',
#  63888: 'Innovation',
#  2471: 'Zombies!!!',
#  209778: 'Magic Maze',
#  102680: 'Trajan',
#  77130: "Sid Meier's Civilization: The Board Game",
#  144733: 'Russian Railroads',
#  9217: 'Saint Petersburg',
#  43111: 'Chaos in the Old World',
#  170042: 'Raiders of the North Sea',
#  127398: 'Legends of Andor',
#  233867: 'Welcome To...',
#  823: 'The Lord of the Rings',
#  48726: 'Alien Frontiers',
#  43443: 'Castle Panic',
#  236457: 'Architects of the West Kingdom',
#  438: 'Scotland Yard',
#  160477: 'Onitama',
#  27588: 'Zooloretto',
#  160499: 'King of New York',
#  29368: 'Last Night on Earth: The Zombie Game',
#  1917: 'Stratego',
#  209010: 'Mechs vs. Minions',
#  216132: 'Clans of Caledonia',
#  59959: 'Letters from Whitechapel',
#  131835: 'Boss Monster: The Dungeon Building Card Game',
#  12692: 'Gloom',
#  194594: 'Dice Forge',
#  91536: 'Quarriors!',
#  215: 'Tichu',
#  20100: 'Wits & Wagers',
#  21241: 'Neuroshima Hex! 3.0',
#  92415: 'Skull',
#  155703: 'Evolution',
#  278: 'Catan Card Game',
#  175914: 'Food Chain Magnate',
#  19857: 'Glory to Rome',
#  27627: 'Talisman (Revised 4th Edition)',
#  45315: 'Dungeon Lords',
#  20551: 'Shogun',
#  83330: 'Mansions of Madness',
#  118048: 'Targi',
#  115746: 'War of the Ring: Second Edition',
#  503: 'Through the Desert',
#  41: "Can't Stop",
#  25292: 'Merchants & Marauders',
#  140620: 'Lewis & Clark: The Expedition',
#  97207: 'Dungeon Petz',
#  811: 'Rummikub',
#  45: 'Perudo',
#  172287: 'Champions of Midgard',
#  155362: "Ca$h 'n Guns (Second Edition)",
#  172818: 'Above and Below',
#  125618: 'Libertalia',
#  25554: 'Notre Dame',
#  119890: 'Agricola: All Creatures Big and Small',
#  156009: 'Port Royal',
#  244522: "That's Pretty Clever!",
#  46213: 'Telestrations',
#  224037: 'Codenames: Duet',
#  180974: 'Potion Explosion',
#  71721: 'Space Hulk: Death Angel – The Card Game',
#  161417: 'Red7',
#  483: 'Diplomacy',
#  176189: 'Zombicide: Black Plague',
#  133038: 'Pathfinder Adventure Card Game: Rise of the Runelords – Base Set',
#  63268: 'Spot it!',
#  239188: 'Chronicles of Crime',
#  171668: 'The Grizzled',
#  140934: 'Arboretum',
#  66188: 'Fresco',
#  233078: 'Twilight Imperium (Fourth Edition)',
#  169426: 'Roll Player',
#  69789: 'Ascension: Deckbuilding Game',
#  155821: 'Inis',
#  37380: 'Roll Through the Ages: The Bronze Age',
#  34119: 'Tales of the Arabian Nights',
#  521: 'Crokinole',
#  2397: 'Backgammon',
#  17226: 'Descent: Journeys in the Dark',
#  43015: 'Hansa Teutonica',
#  2243: 'Yahtzee',
#  150312: 'Welcome to the Dungeon',
#  31627: 'Ticket to Ride: Nordic Countries',
#  182874: 'Grand Austria Hotel',
#  198994: 'Hero Realms',
#  2452: 'Jenga',
#  17133: 'Railways of the World',
#  126042: 'Nations',
#  8098: 'Jungle Speed',
#  9216: 'Goa',
#  191862: 'Imhotep',
#  229853: 'Teotihuacan: City of Gods',
#  197376: 'Charterstone',
#  4390: 'Carcassonne: Hunters and Gatherers',
#  199478: 'Flamme Rouge',
#  146652: 'Legendary Encounters: An Alien Deck Building Game',
#  221107: 'Pandemic Legacy: Season 2',
#  181279: 'Fury of Dracula (Third/Fourth Edition)',
#  699: 'HeroQuest',
#  219513: 'Bärenpark',
#  31594: 'In the Year of the Dragon',
#  1198: 'SET',
#  176396: 'Quadropolis',
#  172386: 'Mombasa',
#  42215: 'Tobago',
#  93260: 'Summoner Wars: Master Set',
#  199042: 'Harry Potter: Hogwarts Battle',
#  185343: 'Anachrony',
#  138161: 'Firefly: The Game',
#  98: 'Axis & Allies',
#  90137: 'Blood Bowl: Team Manager – The Card Game',
#  6472: 'A Game of Thrones',
#  2921: 'The Game of Life',
#  221194: 'Dinosaur Island',
#  1111: 'Taboo',
#  53953: 'Thunderstone',
#  1219: 'Labyrinth',
#  136888: 'Bruges',
#  9609: 'War of the Ring',
#  22545: 'Age of Empires III: The Age of Discovery',
#  217372: 'The Quest for El Dorado',
#  225694: 'Decrypto',
#  19237: "Ca$h 'n Gun$",
#  128621: 'Viticulture',
#  169654: 'Deep Sea Adventure',
#  70149: 'Ora et Labora',
#  25821: "The Werewolves of Miller's Hollow",
#  158600: 'Hanamikoji',
#  97786: 'Small World Underground',
#  27833: 'Steam',
#  150: 'PitchCar',
#  39683: 'At the Gates of Loyang',
#  167355: 'Nemesis',
#  155987: 'Abyss',
#  68425: 'Eminent Domain',
#  286096: 'Tapestry',
#  168435: 'Between Two Cities',
#  160851: 'Lanterns: The Harvest Festival',
#  25417: 'BattleLore',
#  30869: 'Thebes',
#  206718: 'Ethnos',
#  91312: 'Discworld: Ankh-Morpork',
#  254640: 'Just One',
#  33160: 'Endeavor',
#  150658: 'Pandemic: The Cure',
#  125153: 'The Gallerist',
#  63628: 'The Manhattan Project',
#  133848: 'Euphoria: Build a Better Dystopia',
#  1115: 'Poker',
#  20963: 'Fury of Dracula (Second Edition)',
#  127060: 'Bora Bora',
#  139030: 'Mascarade',
#  155068: 'Arcadia Quest',
#  117959: 'Las Vegas',
#  97842: 'Last Will',
#  191189: "Aeon's End",
#  73761: 'K2',
#  143693: 'Glass Road',
#  15818: 'Pickomino',
#  131260: 'Qwixx',
#  21348: 'Ticket to Ride: Märklin',
#  257501: 'KeyForge: Call of the Archons',
#  183840: 'Oh My Goods!',
#  66362: 'Glen More',
#  88: 'Torres',
#  5404: 'Amun-Re',
#  4098: 'Age of Steam',
#  141572: 'Paperback',
#  176920: 'Mission: Red Planet (Second Edition)',
#  15363: 'Nexus Ops',
#  13823: 'Fairy Tale',
#  891: 'Cranium',
#  27746: 'Colosseum',
#  112: 'Condottiere',
#  27708: '1960: The Making of the President',
#  59946: 'Dungeons & Dragons: Castle Ravenloft Board Game',
#  194607: 'Mystic Vale',
#  163968: 'Elysium',
#  220: 'High Society',
#  40398: 'Monopoly Deal Card Game',
#  327: "Loopin' Louie",
#  24181: 'Imperial',
#  146886: 'La Granja',
#  2381: 'Scattergories',
#  183251: 'Karuba',
#  27225: 'Bananagrams',
#  140: 'Pit',
#  394: 'Kahuna',
#  2425: 'Battleship',
#  47: 'Chinatown',
#  203993: 'Lorenzo il Magnifico',
#  200680: 'Agricola (Revised Edition)',
#  196340: 'Yokohama',
#  233371: 'Clank! In! Space!: A Deck-Building Adventure',
#  1234: 'Once Upon a Time: The Storytelling Card Game',
#  12002: 'Jambo',
#  2398: 'Cribbage',
#  2987: "Pirate's Cove",
#  1465: 'Wizard',
#  10: 'Elfenland',
#  203420: 'Exit: The Game – The Abandoned Cabin',
#  11971: 'Cockroach Poker',
#  24068: 'Shadow Hunters',
#  14105: 'Commands & Colors: Ancients',
#  27173: 'Vikings',
#  172081: 'Burgle Bros.',
#  66589: 'Navegador',
#  173090: 'The Game',
#  51: 'Ricochet Robots',
#  30380: 'Cuba',
#  198928: 'Pandemic: Iberia',
#  91514: 'Rhino Hero',
#  13308: 'Niagara',
#  220877: 'Rajas of the Ganges',
#  175117: 'Celestia',
#  11170: 'Heroscape Master Set: Rise of the Valkyrie',
#  21523: 'Runebound (Second Edition)',
#  265736: 'Tiny Towns',
#  256382: 'Disney Villainous',
#  22345: 'Yspahan',
#  59294: 'Runewars',
#  36946: 'Red November',
#  163602: 'XCOM: The Board Game',
#  171499: 'Cacao',
#  2842: 'TransAmerica',
#  915: 'Mystery of the Abbey',
#  247763: 'Underwater Cities',
#  188920: 'This War of Mine: The Board Game',
#  24508: 'Taluva',
#  21882: 'Blue Moon City',
#  172308: 'Broom Service',
#  256226: 'Azul: Stained Glass of Sintra',
#  177524: 'ICECOOL',
#  121408: 'Trains',
#  16986: 'Ubongo',
#  159675: 'Fields of Arle',
#  826: 'Cartagena',
#  137297: 'Rise of Augustus',
#  156336: 'Onirim (Second Edition)',
#  7717: 'Carcassonne: The Castle',
#  7805: 'Fearsome Floors',
#  221965: 'The Fox in the Forest',
#  245638: 'Coimbra',
#  131366: 'Eight-Minute Empire',
#  105134: 'Risk Legacy',
#  138788: 'Dungeon Roll',
#  2952: 'Trivial Pursuit: Genus Edition',
#  193037: 'Dead of Winter: The Long Night',
#  192153: 'Pandemic: Reign of Cthulhu',
#  79828: 'A Few Acres of Snow',
#  169124: "Flick 'em Up!",
#  194879: 'Not Alone',
#  31730: 'Chicago Express',
#  72287: 'Mr. Jack Pocket',
#  177639: 'Raptor',
#  101721: 'Mage Wars Arena',
#  1258: 'Phase 10',
#  144344: 'Rococo',
#  13004: 'The Downfall of Pompeii',
#  172242: 'Exploding Kittens: NSFW Deck',
#  232043: 'Queendomino',
#  55690: 'Kingdom Death: Monster',
#  105551: 'Archipelago',
#  175155: 'Forbidden Stars',
#  590: 'Mille Bornes',
#  179275: 'One Deck Dungeon',
#  85256: 'Timeline: Inventions',
#  7854: 'YINSH',
#  71: 'Civilization',
#  97903: 'Terror in Meeple City',
#  372: 'Schotten Totten',
#  162082: 'Deus',
#  46: 'Medici',
#  475: 'Taj Mahal',
#  22827: 'StarCraft: The Board Game',
#  2375: 'Sequence',
#  105: 'Colossal Arena',
#  122298: 'Morels',
#  128671: 'Spartacus: A Game of Blood and Treachery',
#  82222: 'Xia: Legends of a Drift System',
#  24310: 'The Red Dragon Inn',
#  55670: 'Macao',
#  2083: 'Checkers',
#  148951: 'Tiny Epic Kingdoms',
#  2389: 'Othello',
#  17329: 'Animal Upon Animal',
#  1293: 'Boggle',
#  90419: 'Airlines Europe',
#  242302: 'Space Base',
#  269385: 'The Lord of the Rings: Journeys in Middle-earth',
#  285774: 'Marvel Champions: The Card Game',
#  40628: 'Finca',
#  39938: 'Carson City',
#  929: 'The Great Dalmuti',
#  184921: 'Bunny Kingdom',
#  2281: 'Pictionary',
#  54625: 'Space Hulk (Third Edition)',
#  262712: 'Res Arcana',
#  1829: 'Risk 2210 A.D.',
#  40793: 'Dice Town',
#  171273: 'FUSE',
#  36932: 'Claustrophobia',
#  110277: 'Among the Stars',
#  96913: 'Lancaster',
#  200147: 'Kanagawa',
#  204027: 'Cottage Garden',
#  195421: 'Near and Far',
#  2719: 'Connect Four',
#  3201: 'Lord of the Rings: The Confrontation',
#  83195: 'Ghost Blitz',
#  215311: 'Downforce',
#  176229: 'Tides of Time',
#  205398: 'Citadels',
#  257: 'Kill Doctor Lucky',
#  134726: 'Smash Up: Awesome Level 9000',
#  20437: 'Lords of Vegas',
#  246192: 'Gizmos',
#  143519: 'Quantum',
#  8051: 'Attika',
#  246784: 'Cryptid',
#  159508: 'AquaSphere',
#  234487: 'Altiplano',
#  2093: 'Mahjong',
#  163068: 'Trickerion: Legends of Illusion',
#  65781: 'London',
#  22141: 'Cleopatra and the Society of Architects',
#  155695: 'Age of War',
#  624: 'Quoridor',
#  58281: 'Summoner Wars',
#  526: 'Abalone Classic',
#  15364: 'Vegas Showdown',
#  125678: 'DC Comics Deck-Building Game',
#  29387: 'Zombie Fluxx',
#  244228: 'Reef',
#  263918: 'Cartographers: A Roll Player Tale',
#  161533: 'Lisboa',
#  140933: 'Blueprints',
#  39953: 'A Game of Thrones: The Card Game',
#  38054: 'Snow Tails',
#  30539: 'Get Bit!',
#  284083: 'The Crew: The Quest for Planet Nine',
#  1345: 'Genoa',
#  232832: 'Century: Golem Edition',
#  50750: 'Belfort',
#  207830: '5-Minute Dungeon',
#  2392: 'Mastermind',
#  223321: 'Detective: A Modern Crime Board Game',
#  770: 'Loot',
#  146278: 'Tash-Kalar: Arena of Legends',
#  10093: 'Axis & Allies',
#  180593: 'The Bloody Inn',
#  44163: 'Power Grid: Factory Manager',
#  227789: 'Heaven & Ale',
#  66356: 'Dungeons & Dragons: Wrath of Ashardalon Board Game',
#  12995: 'Dungeon Twister',
#  1269: 'Skip-Bo',
#  2448: 'Kalah',
#  143986: 'CV',
#  266810: 'Paladins of the West Kingdom',
#  201921: 'Tiny Epic Quest',
#  137269: 'Spyrium',
#  102548: 'Dungeon Fighter',
#  56692: 'Parade',
#  5716: 'Balloon Cup',
#  47185: 'Warhammer: Invasion',
#  182134: 'Evolution: Climate',
#  2394: 'Dominoes',
#  192457: 'Cry Havoc',
#  49: 'Mamma Mia!',
#  2407: 'Sorry!',
#  54138: 'Imperial 2030',
#  71836: 'Onirim',
#  42452: 'Rattus',
#  681: 'Quarto',
#  182631: 'Star Realms: Colony Wars',
#  127024: 'Room 25',
#  170416: 'Vast: The Crystal Caverns',
#  18833: 'Lord of the Rings: The Confrontation',
#  559: 'Metro',
#  66056: 'Rivals for Catan',
#  124172: 'Tsuro of the Seas',
#  33604: 'Say Anything',
#  162007: 'Steampunk Rally',
#  34585: 'Keltis',
#  146439: 'BattleLore (Second Edition)',
#  232405: 'Western Legends',
#  148575: 'Marvel Dice Masters: Avengers vs. X-Men',
#  3699: 'Killer Bunnies and the Quest for the Magic Carrot',
#  9446: 'Blue Moon',
#  155624: 'Specter Ops',
#  233398: 'Endeavor: Age of Sail',
#  191977: 'The Castles of Burgundy: The Card Game',
#  166669: 'San Juan (Second Edition)',
#  121: 'Dune',
#  109276: "Kanban: Driver's Edition",
#  228341: 'Pulsar 2849',
#  91872: 'Dungeons & Dragons: The Legend of Drizzt Board Game',
#  15817: 'Manila',
#  245654: 'Railroad Ink: Deep Blue Edition',
#  121410: 'Steam Park',
#  250458: 'Gùgōng',
#  112686: 'Epic Spell Wars of the Battle Wizards: Duel at Mt. Skullzfyre',
#  137408: 'Amerigo',
#  39351: 'Automobile',
#  13642: 'Louis XIV',
#  171233: 'The Big Book of Madness',
#  242: 'Junta',
#  217449: 'NMBR 9',
#  195539: "The Godfather: Corleone's Empire",
#  17223: 'World of Warcraft: The Boardgame',
#  202408: 'Adrenaline',
#  21050: 'Combat Commander: Europe',
#  815: 'Chrononauts',
#  174660: 'New York 1901',
#  103886: 'Star Wars: The Card Game',
#  163: 'Balderdash',
#  136991: 'Loony Quest',
#  712: 'Blood Bowl (Third Edition)',
#  65532: 'Defenders of the Realm',
#  161614: 'Stockpile',
#  1: 'Die Macher',
#  2593: 'Pass the Pigs',
#  203417: 'Exit: The Game – The Secret Lab',
#  213893: 'Yamataï',
#  40765: 'Clash of Cultures',
#  194880: 'Dream Home',
#  58421: 'Egizia',
#  554: 'La Città',
#  714: 'Talisman',
#  10640: 'Doom: The Boardgame',
#  904: 'Dream Factory',
#  156566: 'Lords of Xidit',
#  16395: 'Blokus Duo',
#  1382: "Winner's Circle",
#  1897: 'The Starfarers of Catan',
#  193042: 'Junk Art',
#  222509: 'Lords of Hellas',
#  12962: 'Reef Encounter',
#  126792: 'Myrmes',
#  167400: 'Ashes: Rise of the Phoenixborn',
#  232219: 'Dragon Castle',
#  157526: 'Viceroy',
#  242574: 'Century: Eastern Wonders',
#  1353: "Time's Up!",
#  8989: 'Hansa',
#  274960: 'Point Salad',
#  192135: 'Too Many Bones',
#  168584: 'Love Letter: Batman',
#  25071: 'Munchkin Cthulhu',
#  27710: 'Catan Dice Game',
#  2955: 'Mexica',
#  120: 'Hoity Toity',
#  203416: "Exit: The Game – The Pharaoh's Tomb",
#  72321: 'The Networks',
#  9440: 'Maharaja: The Game of Palace Building in India',
#  4636: 'Clans',
#  221: 'Ikusa',
#  165722: 'KLASK',
#  232918: 'Fallout',
#  102104: 'Star Fluxx',
#  199: 'Manhattan',
#  113997: 'Tajemnicze Domostwo',
#  27364: 'Caylus Magna Carta',
#  28: 'Illuminati (Second Edition)',
#  128271: 'Ginkgopolis',
#  8125: 'Santiago',
#  157403: 'Black Fleet',
#  154246: 'La Isla',
#  181521: 'Warhammer Quest: The Adventure Card Game',
#  28259: 'Cutthroat Caverns',
#  203427: 'Fabled Fruit',
#  229220: 'Santa Maria',
#  234: 'Hannibal: Rome vs. Carthage',
#  152162: 'Diamonds',
#  33154: 'Wasabi!',
#  276025: 'Maracaibo',
#  36345: 'Monty Python Fluxx',
#  66505: 'The Speicherstadt',
#  157809: 'Nations: The Dice Game',
#  32125: 'Felicity: The Cat in the Sack',
#  230080: 'Majesty: For the Realm',
#  192458: '51st State: Master Set',
#  181530: 'Runebound (Third Edition)',
#  189932: 'Tyrants of the Underdark',
#  163166: 'One Night Ultimate Werewolf Daybreak',
#  175324: 'Fog of Love',
#  9203: 'Wings of War: Famous Aces',
#  119: 'Kingdoms',
#  181810: 'Kodama: The Tree Spirits',
#  42776: 'Gears of War: The Board Game',
#  145659: 'Scoville',
#  43868: 'The Adventurers: The Temple of Chac',
#  41916: 'The Magic Labyrinth',
#  4095: 'Star Munchkin',
#  19600: 'Antike',
#  104710: 'Wiz-War (eighth edition)',
#  116998: 'Thunderstone Advance: Towers of Ruin',
#  206941: 'First Class: All Aboard the Orient Express!',
#  200077: 'Mint Works',
#  144592: 'Bruxelles 1893',
#  43528: 'World Without End',
#  421: '1830: Railways & Robber Barons',
#  220520: 'Caverna: Cave vs Cave',
#  201825: 'Ex Libris',
#  124: 'Primordial Soup',
#  176734: 'The Manhattan Project: Energy Empire',
#  269207: 'The Taverns of Tiefenthal',
#  16496: 'Roma',
#  163745: 'Star Wars: Armada',
#  155969: 'Harbour',
#  91: 'Paths of Glory',
#  119432: 'Snowdonia',
#  42052: 'Vinhos',
#  30957: 'Tribune: Primus Inter Pares',
#  142326: 'Eight-Minute Empire: Legends',
#  287954: 'Azul: Summer Pavilion',
#  121297: 'Fleet',
#  35815: 'A Touch of Evil: The Supernatural Game',
#  140603: 'Francis Drake',
#  139976: 'Cthulhu Wars',
#  1159: 'Evo',
#  205359: 'Star Wars: Destiny',
#  494: 'Ave Caesar',
#  2346: 'DVONN',
#  224: 'History of the World',
#  553: 'Chez Geek',
#  70512: 'Luna',
#  179572: 'Dice City',
#  4143: 'Guess Who?',
#  18100: 'China',
#  925: 'Werewolf',
#  26990: 'Container',
#  271896: 'Star Wars: Outer Rim',
#  171669: 'Discoveries: The Journals of Lewis and Clark',
#  184267: 'On Mars',
#  361: 'Hare & Tortoise',
#  4324: 'Risk: The Lord of the Rings',
#  5737: 'Domaine',
#  41002: 'Vasco da Gama',
#  132: 'Caesar & Cleopatra',
#  216459: 'The Lost Expedition',
#  2338: 'Starship Catan',
#  119788: 'Hyperborea',
#  149155: "Dead Man's Draw",
#  2136: 'Pachisi',
#  158900: 'Samurai Spirit',
#  251247: 'Barrage',
#  1041: 'San Marco',
#  62227: 'Labyrinth: The War on Terror, 2001 – ?',
#  282524: 'Horrified',
#  143515: 'Coal Baron',
#  135779: 'A Fake Artist Goes to New York',
#  12902: 'Carcassonne: The City',
#  94: 'Union Pacific',
#  94362: 'Rune Age',
#  104363: 'Rex: Final Days of an Empire',
#  134352: 'Two Rooms and a Boom',
#  137988: 'Zombicide Season 2: Prison Outbreak',
#  104347: 'Santiago de Cuba',
#  121288: 'Dixit: Journey',
#  175621: 'Epic Card Game',
#  25021: 'Sekigahara: The Unification of Japan',
#  18258: 'Mission: Red Planet',
#  106217: 'Hawaii',
#  207336: 'Honshū',
#  25643: 'Arkadia',
#  34887: 'Revolution!',
#  113401: 'Timeline: Events',
#  150999: 'Valley of the Kings',
#  266524: 'PARKS',
#  2386: 'Chinese Checkers',
#  19100: 'Hacienda',
#  193621: 'Joking Hazard',
#  169255: 'A Game of Thrones: The Card Game (Second Edition)',
#  240: 'Britannia',
#  193558: 'The Oracle of Delphi',
#  154809: 'Nippon',
#  25568: 'Metropolys',
#  2596: 'Villa Paletti',
#  245934: 'Carpe Diem',
#  153065: 'Linko!',
#  170: 'Family Business',
#  196326: 'Love Letter Premium',
#  19777: 'Indonesia',
#  60: 'Vinci',
#  35497: 'Fauna',
#  52461: 'Legacy: The Testament of Duke de Crecy',
#  31563: 'Middle-Earth Quest',
#  24742: 'Cold War: CIA vs KGB',
#  98351: 'Core Worlds',
#  1513: 'The Republic of Rome',
#  129948: 'The Palaces of Carrara',
#  257499: 'Arkham Horror (Third Edition)',
#  34127: 'Ticket to Ride: The Card Game',
#  148319: 'Tragedy Looper',
#  878: 'Wyatt Earp',
#  37628: 'Haggis',
#  103: 'Titan',
#  132372: 'Guildhall',
#  21441: 'Mykerinos',
#  15: 'Cosmic Encounter',
#  528: 'ZÈRTZ',
#  21632: 'To Court the King',
#  1231: 'Bausack',
#  18803: 'Black Stories',
#  156858: 'Black Orchestra',
#  253284: 'Ticket to Ride: New York',
#  212402: 'The Grimm Forest',
#  16747: 'Tumblin-Dice',
#  256: 'Mississippi Queen',
#  22038: 'Warrior Knights',
#  170561: 'Valeria: Card Kingdoms',
#  144553: 'The Builders: Middle Ages',
#  224783: 'Vindication',
#  88408: 'Nightfall',
#  3685: 'Hammer of the Scots',
#  6411: 'Blokus 3D',
#  134253: 'Hostage Negotiator',
#  5048: 'Candy Land',
#  193214: 'Meeple Circus',
#  160010: 'Conan',
#  269210: 'Twice as Clever!',
#  194626: 'Happy Salmon',
#  1403: 'Turn the Tide',
#  35570: "Tinners' Trail",
#  244711: 'Newton',
#  986: 'Babel',
#  175640: 'Vinhos Deluxe Edition',
#  65515: 'Nuns on the Run',
#  95527: 'Madeira',
#  17025: 'Friday the 13th',
#  181687: 'The Pursuit of Happiness',
#  119506: 'Freedom: The Underground Railroad',
#  22825: 'Tide of Iron',
#  197070: 'Massive Darkness',
#  42487: 'Lost Cities: The Board Game',
#  9625: 'Struggle of Empires',
#  71671: 'Yggdrasil',
#  5894: 'Twister',
#  13122: 'Antiquity',
#  39339: 'Android',
#  38159: 'Ultimate Werewolf: Ultimate Edition',
#  233312: 'Stuffed Fables',
#  151347: 'Millennium Blades',
#  180511: 'Shakespeare',
#  236191: 'London (Second Edition)',
#  119591: 'Rialto',
#  18866: 'Shear Panic',
#  36235: 'The Duke',
#  82168: 'Escape from the Aliens in Outer Space',
#  191231: 'Via Nebula',
#  6887: 'Hearts',
#  29678: 'Munchkin Quest',
#  55600: 'Shipyard',
#  72225: 'CO₂',
#  1339: 'Dungeon!',
#  131325: 'Timeline: Diversity',
#  233247: 'Civilization: A New Dawn',
#  158275: 'Marvel Dice Masters: Uncanny X-Men',
#  34084: "Witch's Brew",
#  233020: 'Fireball Island: The Curse of Vul-Kar',
#  4396: "Odin's Ravens",
#  2163: 'Space Hulk',
#  198454: 'When I Dream',
#  151004: 'Smash Up: Science Fiction Double Feature',
#  37196: 'Sorry! Sliders',
#  204305: 'Sherlock Holmes Consulting Detective: Jack the Ripper & West End Adventures',
#  155873: 'Power Grid Deluxe: Europe/North America',
#  128996: '1775: Rebellion',
#  4491: 'Cave Troll',
#  177590: '13 Days: The Cuban Missile Crisis',
#  1117: "You're Bluffing!",
#  54137: 'Battle Sheep',
#  5432: 'Chutes and Ladders',
#  145639: 'Coconuts',
#  281259: 'The Isle of Cats',
#  197443: 'Fugitive',
#  118063: 'Android: Infiltration',
#  131646: 'Merchant of Venus (Second Edition)',
#  130176: 'Tales & Games: The Hare & the Tortoise',
#  17392: 'Here I Stand',
#  264220: 'Tainted Grail: The Fall of Avalon',
#  168679: 'Flip City',
#  183880: 'Risk: Star Wars Edition',
#  131287: 'Panamax',
#  115: "I'm the Boss!",
#  3307: 'Wallenstein',
#  216734: 'Dice Throne: Season One',
#  180852: 'Tiny Epic Western',
#  243: 'Advanced Squad Leader',
#  151022: 'Baseball Highlights: 2045',
#  95103: 'Fortune and Glory: The Cliffhanger Game',
#  26566: 'Homesteaders',
#  176558: 'Mafia de Cuba',
#  258036: 'Between Two Castles of Mad King Ludwig',
#  154458: 'Akrotiri',
#  150145: 'Skull King',
#  154386: 'Medieval Academy',
#  39206: 'Click Clack Lumberjack',
#  3737: 'Operation',
#  249: 'Lifeboats',
#  24417: 'Factory Fun',
#  551: 'Battle Cry',
#  234277: 'Nusfjord',
#  117915: 'Yedo',
#  234190: 'Unstable Unicorns',
#  481: 'Carolus Magnus',
#  209418: 'Dominion (Second Edition)',
#  101785: 'D-Day Dice',
#  176165: 'Dale of Merchants',
#  21920: 'Leonardo da Vinci',
#  106662: 'Power Grid: The First Sparks',
#  99975: 'Timeline: Discoveries',
#  179172: 'Unfair',
#  112138: 'Krosmaster: Arena',
#  134453: 'The Little Prince: Make Me a Planet',
#  45986: 'Stronghold',
#  175199: 'Mottainai',
#  15985: 'Blood Bowl: Living Rulebook',
#  340: "Frank's Zoo",
#  1540: 'BattleTech',
#  8107: 'Risk: The Lord of the Rings Trilogy Edition',
#  491: 'Web of Power',
#  108784: 'Ascension: Storm of Souls',
#  943: 'Ligretto',
#  191051: 'Outlive',
#  174785: 'Mare Nostrum: Empires',
#  19999: 'Aton',
#  855: 'Java',
#  217085: 'Unearth',
#  241724: 'Villagers',
#  106: 'Mystery Rummy: Jack the Ripper',
#  223040: 'Fantasy Realms',
#  146791: 'Shadows of Brimstone: City of the Ancients',
#  129051: 'Le Havre: The Inland Port',
#  135382: 'Shadowrun: Crossfire',
#  382: 'Heimlich & Co.',
#  638: 'Hera and Zeus',
#  170771: 'Sword & Sorcery',
#  2165: 'Pokémon Trading Card Game',
#  260428: 'Pandemic: Fall of Rome',
#  226320: 'My Little Scythe',
#  244536: 'Tiny Epic Zombies',
#  162286: 'Super Motherload',
#  902: 'Meuterer',
#  142992: 'Gravwell: Escape from the 9th Dimension',
#  30645: 'Tammany Hall',
#  16267: 'Trans Europa',
#  143185: 'Smash Up: The Obligatory Cthulhu Set',
#  73171: 'Earth Reborn',
#  172047: 'The Others',
#  31497: 'Oregon',
#  159109: 'XenoShyft: Onslaught',
#  634: 'River Dragons',
#  19526: 'Elasund: The First City',
#  156546: 'Monikers',
#  123096: 'Space Cadets',
#  7: 'Cathedral',
#  619: 'The Bottle Imp',
#  24827: 'Traders of Osaka',
#  192836: 'The Colonists',
#  6707: 'Age of Mythology: The Boardgame',
#  128667: 'Samurai Sword',
#  66171: 'Dragonheart',
#  12477: 'Bootleggers',
#  71061: 'DungeonQuest (Third Edition)',
#  219215: 'Werewords',
#  117985: 'Star Trek: Catan',
#  11901: 'Tic-Tac-Toe',
#  3931: 'Mare Nostrum',
#  197831: 'Dark Souls: The Board Game',
#  176083: 'Hit Z Road',
#  95064: 'Ascension: Return of the Fallen',
#  79127: 'Star Trek: Fleet Captains',
#  205610: 'A Game of Thrones: Hand of the King',
#  31999: 'TZAAR',
#  262215: 'Blackout: Hong Kong',
#  30381: 'Hamburgum',
#  41010: 'My First Carcassonne',
#  492: "Aladdin's Dragons",
#  98229: 'Pictomania',
#  1035: 'Squad Leader',
#  142379: 'Escape Plan',
#  251678: 'Railroad Ink: Blazing Red Edition',
#  29223: 'Marrakech',
#  195544: 'Tides of Madness',
#  168917: 'Smash Up: Pretty Pretty Smash Up',
#  25261: 'Tannhäuser',
#  31105: 'Archaeology: The Card Game',
#  201: 'The Rose King',
#  1410: 'Trouble',
#  271324: "It's a Wonderful World",
#  141517: 'A Study in Emerald',
#  178336: "World's Fair 1893",
#  165950: 'Beasty Bar',
#  40393: 'FITS',
#  108906: 'Thunder Alley',
#  20545: "Rory's Story Cubes",
#  3284: 'Star Wars: Epic Duels',
#  218333: 'Rhino Hero: Super Battle',
#  217: 'A la carte',
#  86955: 'Munchkin Zombies',
#  111124: 'Dark Moon',
#  242639: 'Treasure Island',
#  1042: "Dragon's Gold",
#  111341: 'The Great Zimbabwe',
#  12005: 'Around the World in 80 Days',
#  36553: "Time's Up! Title Recall!",
#  339: 'Quiddler',
#  19841: 'Pentago',
#  157789: 'Pandemic: Contagion',
#  ...}

# %% [markdown]
# ## make the matrix

# %%
from scipy.sparse import csr_matrix

def create_X(df):
    """
    Generates a sparse matrix from ratings dataframe.
    
    Args:
        df: pandas dataframe
    
    Returns:
        X: sparse matrix
        user_mapper: dict that maps user id's to user indices
        user_inv_mapper: dict that maps user indices to user id's
        movie_mapper: dict that maps movie id's to movie indices
        movie_inv_mapper: dict that maps movie indices to movie id's
    """
    
    N = df["user_id"].nunique() # number of users
    M= df["game_id"].nunique() # number of games
    
    user_mapper = dict(zip(np.unique(df["user_id"]), list(range(N))))
    game_mapper = dict(zip(np.unique(df["game_id"]), list(range(M))))
    
    user_inv_mapper = dict(zip(list(range(N)), np.unique(df["user_id"])))
    game_inv_mapper = dict(zip(list(range(M)), np.unique(df["game_id"])))
    
    user_index = [user_mapper[i] for i in df["user_id"]]
    game_index = [game_mapper[i] for i in df["game_id"]]
    
    X = csr_matrix((df["rating"], (game_index, user_index)), shape=(M,N))
    
    return X, user_mapper, game_mapper, user_inv_mapper, game_inv_mapper

# %%
ratings.user_id.unique()
# Out:
# array(['Torsten', 'mitnachtKAUBO-I', 'avlawn', ..., 'rielnano',
#        'Lost_Titan_Legacy', 'smedzz31'], dtype=object)

# %%
# encode the user ids
from sklearn.preprocessing import LabelEncoder

# Step 1. Instantiate the model (label encoding)
le = LabelEncoder() 
le.fit_transform(ratings['user_id'])

# Step 2. Fit the variable to the instatiated model
ratings['user_id'] = le.fit_transform(ratings['user_id'])
ratings.head(10)
# Out:
#    user_id  rating  game_id     title
# 0   162393    10.0    30549  Pandemic
# 1   282186    10.0    30549  Pandemic
# 2   188488    10.0    30549  Pandemic
# 3   104525    10.0    30549  Pandemic
# 4   102294    10.0    30549  Pandemic
# 5   202289    10.0    30549  Pandemic
# 6   259457    10.0    30549  Pandemic
# 7    34278    10.0    30549  Pandemic
# 8   237240    10.0    30549  Pandemic
# 9   199851    10.0    30549  Pandemic

# %%
ratings.user_id.nunique()
# Out:
# 351049

# %%
ratings.tail(10)
# Out:
#           user_id  rating  game_id              title
# 15823259    94173     9.0   281515  Company of Heroes
# 15823260   180855     9.0   281515  Company of Heroes
# 15823261   320655     9.0   281515  Company of Heroes
# 15823262    61909     9.0   281515  Company of Heroes
# 15823263   129799     9.0   281515  Company of Heroes
# 15823264    50913     8.0   281515  Company of Heroes
# 15823265   124124     8.0   281515  Company of Heroes
# 15823266    22867     7.0   281515  Company of Heroes
# 15823267    65652     6.0   281515  Company of Heroes
# 15823268   132441     1.0   281515  Company of Heroes

# %%
ratings.sort_values(by=["rating"],ascending=True)
# Out:
#           user_id        rating  game_id  \
# 2439405     59027  1.401300e-45       42
# 9924871    240149  1.000000e-30     5432
# 8654503    182310  1.000000e-04     3699
# 15015812   182310  1.000000e-03     9782
# 15250333   147014  1.000000e-03    18041
# ...           ...           ...      ...
# 3726695    327193  1.000000e+01   237182
# 3726694    288547  1.000000e+01   237182
# 3726693    139590  1.000000e+01   237182
# 3726691    331038  1.000000e+01   237182
# 0          162393  1.000000e+01    30549
#
#                                                       title
# 2439405                                  Tigris & Euphrates
# 9924871                                  Chutes and Ladders
# 8654503   Killer Bunnies and the Quest for the Magic Carrot
# 15015812                Battle of the Bands: Encore Edition
# 15250333                                        Bunco Party
# ...                                                     ...
# 3726695                                                Root
# 3726694                                                Root
# 3726693                                                Root
# 3726691                                                Root
# 0                                                  Pandemic
#
# [15823269 rows x 4 columns]

# %%
# number of ratings per user
userfreq = ratings[["user_id", "game_id"]].groupby("user_id").count().reset_index()
userfreq.columns = ["user_id","no_ratings"]
userfreq.sort_values(by="no_ratings")
# Out:
#         user_id  no_ratings
# 245030   245030           1
# 169471   169471           1
# 147351   147351           1
# 49107     49107           1
# 95683     95683           1
# ...         ...         ...
# 66952     66952        4602
# 342435   342435        4811
# 41655     41655        4876
# 161600   161600        4950
# 267289   267289        6027
#
# [351049 rows x 2 columns]

# %%
ratings = ratings.merge(userfreq, on="user_id")
ratings
# Out:
#           user_id  rating  game_id              title  no_ratings
# 0          162393    10.0    30549           Pandemic        1358
# 1          162393    10.0    68448          7 Wonders        1358
# 2          162393    10.0   178900          Codenames        1358
# 3          162393    10.0    31260           Agricola        1358
# 4          162393    10.0   148228           Splendor        1358
# ...           ...     ...      ...                ...         ...
# 15823264      811    10.0   281515  Company of Heroes           1
# 15823265   146512    10.0   281515  Company of Heroes           1
# 15823266   307953    10.0   281515  Company of Heroes           1
# 15823267    94173     9.0   281515  Company of Heroes           1
# 15823268   320655     9.0   281515  Company of Heroes           1
#
# [15823269 rows x 5 columns]

# %%
# actually creating the matrix

X, user_mapper, game_mapper, user_inv_mapper, game_inv_mapper = create_X(ratings)

# %%
X
# Out:
# <19330x351049 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15823269 stored elements in Compressed Sparse Row format>

# %% [raw]
# # turn to sparse matrix into dataframe
#
# usermatrix = pd.DataFrame(X.todense(), index=ratings2.game_id.unique(), columns = ratings2.user_id.unique())
# usermatrix

# %%
# calculate the sparsity of our matrix

sparsity = X.count_nonzero()/(X.shape[0]*X.shape[1])

print("The sparsity of this matrix is ", round(sparsity*100,2))
# Out:
# The sparsity of this matrix is  0.23

# %% [raw]
# # sparsity is a problem if below 0.5% so this is fine

# %% [markdown]
# ## k-nearest neighbors

# %%
from sklearn.neighbors import NearestNeighbors

KNN = NearestNeighbors(n_neighbors=10, metric="cosine") # how to pick the metric????
KNN.fit(X)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=10)

# %%
# use the mapper to find the index of the book we want to assess

gameindex = game_mapper[10]
gameindex
# Out:
# 9

# %%
game_toassess = X[9]
game_toassess
# Out:
# <1x351049 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7855 stored elements in Compressed Sparse Row format>

# %%
# find the nearest neighbors to this book
neig = KNN.kneighbors(game_toassess, return_distance=False)
neig
# Out:
# array([[  9, 673,  84,  80,  51, 109, 429, 406, 218, 311]], dtype=int64)

# %%
# use the inverse mapper to find the ids of the neighbours

neig_ids = []
for i in range(1,10):
    n = neig.item(i)
    neig_ids.append(game_inv_mapper[n])

# %%
neig_ids
# Out:
# [826, 93, 88, 54, 120, 503, 475, 256, 361]

# %%
# use the ids to find the titles

print("because you enjoyed playing:",gametitles[9])
for i in neig_ids:
    print(gametitles[i])
# Out:
# because you enjoyed playing: El Caballero
# Cartagena
# El Grande
# Torres
# Tikal
# Hoity Toity
# Through the Desert
# Taj Mahal
# Mississippi Queen
# Hare & Tortoise

# %% [markdown]
# ## make a function to do it

# %%
def rec_games(game_id, df, X, k, metric="cosine"):
    """
    Finds k-nearest neighbours for a given book id.
    
    Args:
        book_id: id of the book of interest
        X: user-item utility matrix
        k: number of similar book to retrieve
        metric: distance metric for kNN calculations
    
    Returns:
        list of k similar book ID's
    """
        
    neighbour_ids = []
        
    game_ind = game_mapper[game_id]
    game_to_assess = X[game_ind]
    KNN = NearestNeighbors(n_neighbors=k, metric=metric)
        
    KNN.fit(X)
        
    neighbour = KNN.kneighbors(game_to_assess, return_distance=False)
        
    for i in range(1,k):
        n = neighbour.item(i)
        neighbour_ids.append(game_inv_mapper[n])
            
    game_titles = dict(zip(df["game_id"], df["title"]))
    game_title = game_titles[game_id]
        
    print("Because you enjoyed playing:", game_title, ", I think you would enjoy these:")
    for i in neighbour_ids:
        print(game_titles[i])

# %%
rec_games(10, info, X, k=10)
# Out:
# Because you enjoyed playing: Elfenland , I think you would enjoy these:
# Cartagena
# El Grande
# Torres
# Tikal
# Hoity Toity
# Through the Desert
# Taj Mahal
# Mississippi Queen
# Hare & Tortoise

# %%
info[info.title.str.contains('Pandemic')]
# Out:
#           game_id                               title
# 0           30549                            Pandemic
# 2893       161936           Pandemic Legacy: Season 1
# 5362289    221107           Pandemic Legacy: Season 2
# 6539377    150658                  Pandemic: The Cure
# 6545946    198928                    Pandemic: Iberia
# 7406011    192153          Pandemic: Reign of Cthulhu
# 9929732    260428              Pandemic: Fall of Rome
# 9936696    157789                 Pandemic: Contagion
# 11432557   234671               Pandemic: Rising Tide
# 12224758   280789            Pandemic: Rapid Response
# 14710440   301919  Pandemic: Hot Zone – North America
# 15375100   314040           Pandemic Legacy: Season 0

# %%
rec_games(30549, info, X, k=10)
# Out:
# Because you enjoyed playing: Pandemic , I think you would enjoy these:
# 7 Wonders
# Carcassonne
# Dominion
# Catan
# Ticket to Ride
# Codenames
# Small World
# King of Tokyo
# Love Letter

# %%
info[info.title.str.contains('Nemesis')]
# Out:
#           game_id                     title
# 6538181    167355                   Nemesis
# 15467076   197076       Nemesis: Burma 1944
# 15671818   310100         Nemesis: Lockdown
# 15780467   200959  1813: Napoleon's Nemesis

# %%
rec_games(167355, info, X, k=10)
# Out:
# Because you enjoyed playing: Nemesis , I think you would enjoy these:
# Lords of Hellas
# Rising Sun
# Blood Rage
# Mansions of Madness: Second Edition
# Scythe
# Terraforming Mars
# Root
# Star Wars: Rebellion
# Tainted Grail: The Fall of Avalon

# %%
info[info.title.str.contains('Clank')]
# Out:
#           game_id                                         title
# 7980       201808             Clank!: A Deck-Building Adventure
# 6544255    233371  Clank! In! Space!: A Deck-Building Adventure
# 11027330   266507      Clank! Legacy: Acquisitions Incorporated

# %%
rec_games(266507, info, X, k=10)
# Out:
# Because you enjoyed playing: Clank! Legacy: Acquisitions Incorporated , I think you would enjoy these:
# Clank! In! Space!: A Deck-Building Adventure
# Clank!: A Deck-Building Adventure
# The Quacks of Quedlinburg
# Space Base
# Everdell
# Roll Player
# Wingspan
# Tapestry
# Charterstone

# %%
info[info.title.str.contains('Everrain')]
# Out:
#           game_id         title
# 15797255   252315  The Everrain

# %%
rec_games(252315, info, X, k=10)
# Out:
# Because you enjoyed playing: The Everrain , I think you would enjoy these:
# Oathsworn: Into the Deepwood
# Solomon Kane
# Warhammer Underworlds: Dreadfane
# Limbo: Eternal War
# Mighty Morphin Power Rangers Game
# Waste Knights: Second Edition
# The Great Wall
# Krosmaster: Blast
# Village Attacks

# %%
info[info.title.str.contains('Twilight')]
# Out:
#           game_id                                              title
# 2793        12333                                  Twilight Struggle
# 3658174     12493                  Twilight Imperium (Third Edition)
# 5359694    233078                 Twilight Imperium (Fourth Edition)
# 13318833   180199  Colonial Twilight: The French-Algerian War, 19...
# 13383735       24                                  Twilight Imperium
# 13756126    26055                 Twilight Imperium (Second Edition)
# 14506148   191364                                  Twilight Squabble
# 14844496    63385                        Anima: Twilight of the Gods
# 14932425    21779                         1914: Twilight in the East
# 15298572   206904                               Twilight of the Gods
# 15306786     2902                          Twilight Imperium: Armada
# 15328881   189664       The Hunted: Twilight of the U-Boats, 1943-45
# 15496224    33225         Clue:  The Twilight Zone – Tower of Terror
# 15600691     5875                       Last Battle: Twilight – 2000
# 15648644    22406  Twilight of the Ottomans: World War I in the M...
# 15691652   164279           Twilight Sparkle's Secret Shipfic Folder
# 15712982    41068                           Twilight: The Board Game
# 15720524     3650                                   The Twilight War
# 15756419    63379  The Twilight Saga: New Moon – The Movie Board ...
# 15782846    14746                         Twilight's Last Gleaming 2
# 15791174    11473                           Twilight's Last Gleaming

# %%
rec_games(233078, info, X, k=10)
# Out:
# Because you enjoyed playing: Twilight Imperium (Fourth Edition) , I think you would enjoy these:
# Star Wars: Rebellion
# Scythe
# Terraforming Mars
# Blood Rage
# Rising Sun
# Root
# Twilight Imperium (Third Edition)
# Gloomhaven
# Through the Ages: A New Story of Civilization

# %%
info[info.title.str.contains('Flatline')]
# Out:
#           game_id     title
# 12481842   216597  Flatline

# %%
rec_games(216597, info, X, k=10)
# Out:
# Because you enjoyed playing: Flatline , I think you would enjoy these:
# FUSE
# Flip Ships
# Sentient
# Covert
# Ex Libris
# Pandemic: The Cure
# Magic Maze
# Quadropolis
# Potion Explosion
